# %%
import cv2
import numpy as np
from skimage import io
from matplotlib import pyplot as plt
from google.colab.patches import cv2_imshow

def url_to_image(url):
  print("downloading %s" % (url))
  return cv2.cvtColor(io.imread(url), cv2.COLOR_BGR2RGB)

# %%
def capture_text(url, block_size, c, hColor, templateWindowSize, searchWindowSize):
  img = url_to_image(url)
  grayscaled = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
  threshold = cv2.adaptiveThreshold(grayscaled, 255,
                          cv2.ADAPTIVE_THRESH_GAUSSIAN_C,
                          cv2.THRESH_BINARY, block_size, c)

  # retval, threshold = cv2.threshold(grayscaled, 50, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)
  # cv2_imshow(grayscaled)
  # cv2_imshow(threshold)

  image4 = cv2.fastNlMeansDenoising(threshold, None, hColor, templateWindowSize, searchWindowSize)
  cv2_imshow(image4)

# %%
url2 = "https://raw.githubusercontent.com/mdavydov/ComputerVisionCourse/master/tasks/tnotes/t1.jpg"
capture_text(url2, block_size = 5, c = 9, hColor = 20, templateWindowSize = 16, searchWindowSize = 20)
# Out:
# downloading https://raw.githubusercontent.com/mdavydov/ComputerVisionCourse/master/tasks/tnotes/t1.jpg
# <PIL.Image.Image image mode=L size=360x480 at 0x7FD55538BB38>

# %%
url2 = "https://raw.githubusercontent.com/mdavydov/ComputerVisionCourse/master/tasks/tnotes/t2.jpg"
capture_text(url2, block_size = 15, c = 5, hColor = 80, templateWindowSize = 7, searchWindowSize = 15)
# Out:
# downloading https://raw.githubusercontent.com/mdavydov/ComputerVisionCourse/master/tasks/tnotes/t2.jpg
# <PIL.Image.Image image mode=L size=360x480 at 0x7FD55538BD68>

# %%
url2 = "https://raw.githubusercontent.com/mdavydov/ComputerVisionCourse/master/tasks/tnotes/t3.jpg"
capture_text(url2, block_size = 7, c = 5, hColor = 80, templateWindowSize = 7, searchWindowSize = 15)
# Out:
# downloading https://raw.githubusercontent.com/mdavydov/ComputerVisionCourse/master/tasks/tnotes/t3.jpg
# <PIL.Image.Image image mode=L size=225x480 at 0x7FD555330B00>

# %%
url2 = "https://raw.githubusercontent.com/mdavydov/ComputerVisionCourse/master/tasks/tnotes/t4.jpg"
capture_text(url2, block_size = 9, c = 7, hColor = 30, templateWindowSize = 7, searchWindowSize = 15)
# Out:
# downloading https://raw.githubusercontent.com/mdavydov/ComputerVisionCourse/master/tasks/tnotes/t4.jpg
# <PIL.Image.Image image mode=L size=480x360 at 0x7FD5553305C0>

# %%
url2 = "https://raw.githubusercontent.com/mdavydov/ComputerVisionCourse/master/tasks/tnotes/t5.jpg"
capture_text(url2, block_size = 3, c = 7, hColor = 50, templateWindowSize = 7, searchWindowSize = 15)
# Out:
# downloading https://raw.githubusercontent.com/mdavydov/ComputerVisionCourse/master/tasks/tnotes/t5.jpg
# <PIL.Image.Image image mode=L size=360x480 at 0x7FD55538BE48>

# %%
url2 = "https://raw.githubusercontent.com/mdavydov/ComputerVisionCourse/master/tasks/tnotes/t6.jpg"
capture_text(url2, block_size = 5, c = 5, hColor = 35, templateWindowSize = 7, searchWindowSize = 15)
# Out:
# downloading https://raw.githubusercontent.com/mdavydov/ComputerVisionCourse/master/tasks/tnotes/t6.jpg
# <PIL.Image.Image image mode=L size=480x360 at 0x7FD55538B278>
